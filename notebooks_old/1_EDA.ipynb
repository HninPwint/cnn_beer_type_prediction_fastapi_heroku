# %%
import pandas as pd
import numpy as np

import os
import sys
sys.path.append(os.path.abspath('..'))

from src.data.utility import DataReader, BeerData

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %load_ext autoreload
# %autoreload 2

# %%
# Instantiate the custom data reader class
data_reader = DataReader()

# %%
# Load Raw Train Data
train_df = data_reader.read_data(BeerData.RAW)

# %%
train_df.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
train_df.describe()
# Out:
#          brewery_id   review_time  review_overall  review_aroma  \
# count  1.586614e+06  1.586614e+06    1.586614e+06  1.586614e+06
# mean   3.130099e+03  1.224089e+09    3.815581e+00  3.735636e+00
# std    5.578104e+03  7.654427e+07    7.206219e-01  6.976167e-01
# min    1.000000e+00  8.406720e+08    0.000000e+00  1.000000e+00
# 25%    1.430000e+02  1.173224e+09    3.500000e+00  3.500000e+00
# 50%    4.290000e+02  1.239203e+09    4.000000e+00  4.000000e+00
# 75%    2.372000e+03  1.288568e+09    4.500000e+00  4.000000e+00
# max    2.800300e+04  1.326285e+09    5.000000e+00  5.000000e+00
#
#        review_appearance  review_palate  review_taste      beer_abv  \
# count       1.586614e+06   1.586614e+06  1.586614e+06  1.518829e+06
# mean        3.841642e+00   3.743701e+00  3.792860e+00  7.042387e+00
# std         6.160928e-01   6.822184e-01  7.319696e-01  2.322526e+00
# min         0.000000e+00   1.000000e+00  1.000000e+00  1.000000e-02
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 13 columns):
# brewery_id            1586614 non-null int64
# brewery_name          1586599 non-null object
# review_time           1586614 non-null int64
# review_overall        1586614 non-null float64
# review_aroma          1586614 non-null float64
# review_appearance     1586614 non-null float64
# review_profilename    1586266 non-null object
# beer_style            1586614 non-null object
# review_palate         1586614 non-null float64
# review_taste          1586614 non-null float64
# beer_name             1586614 non-null object
# beer_abv              1518829 non-null float64
# beer_beerid           1586614 non-null int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 157.4+ MB

# %%
# df_cleaned.isna().sum()

# %%
ddd = train_df[train_df['brewery_name'].isnull()]

# %%
print("org shape", train_df.shape)
print("cleand shape", train_df.shape)
train_df.head()
# Out:
# org shape (1586614, 13)
# cleand shape (1586614, 13)
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# ...

# %% [markdown]
# ### Exmine the target class Count

# %%
### Exmine the target class count
target_class = train_df['beer_style'].value_counts().reset_index()

print("shape", target_class.shape)
target_class

#train_df['beer_style'].value_counts()
# Out:
# shape (104, 2)
#                                 index  beer_style
# 0                        American IPA      117586
# 1      American Double / Imperial IPA       85977
# 2             American Pale Ale (APA)       63469
# 3              Russian Imperial Stout       54129
# 4    American Double / Imperial Stout       50705
# ..                                ...         ...
# 99                               Gose         686
# 100                              Faro         609
# 101                        Roggenbier         466
# 102                             Kvass         297
# 103                          Happoshu         241
#
# [104 rows x 2 columns]

# %% [markdown]
# There are 104 types of beer

# %%
# Exmine the  brewery_name count
aaa = train_df['brewery_name'].value_counts().reset_index()
aaa.rename(columns={"index": "brewery_name", "brewery_name": "count"})
aaa.shape
# Out:
# (5742, 2)

# %%
aaa
# Out:
#                                                   index  brewery_name
# 0                    Boston Beer Company (Samuel Adams)         39444
# 1                                  Dogfish Head Brewery         33839
# 2                                     Stone Brewing Co.         33066
# 3                             Sierra Nevada Brewing Co.         28751
# 4                                  Bell's Brewery, Inc.         25191
# ...                                                 ...           ...
# 5737                              Tobiishi Kikai Sangyo             1
# 5738                                 Cervecería El Buho             1
# 5739  Arriba Mexican Grill & Casa Arriba Brewing Com...             1
# 5740                           Elizabeth Street Brewery             1
# 5741                              Panimoravintola Koulu             1
#
# [5742 rows x 2 columns]

# %%
# bbb =  train_df['brewery_name'].value_counts().reset_index()
# bbb.rename(columns = {"index": "brewery_name", "brewery_name": "count"})

# %%
# np.unique(y_val)

# %%
# Out:
# (1586614, 13)

# %%
data_reader.plot_correlation(train_df, ["brewery_id", "beer_beerid"])

# %%
corr_matrix = train_df.corr()
corr_matrix
#print(corr_matrix["beer_style"].sort_values(ascending=False))
# Out:
#                    brewery_id  review_time  review_overall  review_aroma  \
# brewery_id           1.000000     0.220954       -0.009331      0.019069
# review_time          0.220954     1.000000        0.028724      0.067453
# review_overall      -0.009331     0.028724        1.000000      0.616013
# review_aroma         0.019069     0.067453        0.616013      1.000000
# review_appearance    0.001993     0.058233        0.501732      0.561029
# review_palate       -0.000499     0.057247        0.701914      0.616947
# review_taste        -0.002672     0.044498        0.789816      0.716776
# beer_abv             0.063731     0.144885        0.138512      0.332570
# beer_beerid          0.424097     0.461535        0.003794      0.077669
#
#                    review_appearance  review_palate  review_taste  beer_abv  \
# brewery_id                  0.001993      -0.000499     -0.002672  0.063731
# review_time                 0.058233       0.057247      0.044498  0.144885
# ...
